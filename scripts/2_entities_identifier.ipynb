# %%
import pandas as pd
import re
import hashlib
from collections import defaultdict
from cdmx_entity_patterns_fixed import GOV_ENTITY_REGEX
# Use precise patterns instead of generic ones
from federal_laws_patterns_precise import LAWS_REGEX as FEDERAL_LAWS_REGEX, LAW_CATEGORIES as FEDERAL_LAW_CATEGORIES
from cdmx_laws_patterns_precise import LAWS_REGEX as CDMX_LAWS_REGEX, LAW_CATEGORIES as CDMX_LAW_CATEGORIES

# %%
# Load the environmental law data
df = pd.read_csv('/Users/alexa/Projects/cdmx_kg/data/identifiers_0_half.csv')

# %%
def extract_context_window(text, match_start, match_end, words_before=30, words_after=30):
    """
    Extract context window around a match with specified number of words before and after.
    
    Args:
        text: Full text string
        match_start: Start position of the match
        match_end: End position of the match  
        words_before: Number of words to include before the match
        words_after: Number of words to include after the match
    
    Returns:
        Dictionary with context information
    """
    import re
    
    # Split text into words using regex (handles punctuation better)
    words = re.findall(r'\b\w+\b|\S', text)
    
    # Find word positions for the match
    char_to_word = {}
    char_pos = 0
    
    for word_idx, word in enumerate(words):
        word_start = text.find(word, char_pos)
        word_end = word_start + len(word)
        
        for char_idx in range(word_start, word_end):
            char_to_word[char_idx] = word_idx
            
        char_pos = word_end
    
    # Find word indices for match boundaries
    match_start_word = char_to_word.get(match_start, 0)
    match_end_word = char_to_word.get(match_end - 1, len(words) - 1)
    
    # Calculate context boundaries
    context_start = max(0, match_start_word - words_before)
    context_end = min(len(words), match_end_word + words_after + 1)
    
    # Extract context words
    before_words = words[context_start:match_start_word]
    match_words = words[match_start_word:match_end_word + 1]
    after_words = words[match_end_word + 1:context_end]
    
    # Join back to text
    before_text = ' '.join(before_words) if before_words else ""
    match_text = ' '.join(match_words)
    after_text = ' '.join(after_words) if after_words else ""
    
    # Create full context
    full_context = f"{before_text} **{match_text}** {after_text}".strip()
    
    return {
        'before_context': before_text.strip(),
        'matched_entity': match_text.strip(), 
        'after_context': after_text.strip(),
        'full_context': full_context,
        'words_before_count': len(before_words),
        'words_after_count': len(after_words)
    }

# %% [markdown]
# # Extraction of laws and government entities

# %%
def extract_entities_with_true_hierarchy(df, text_column='text', section_column='document_section_title'):
    """    
    TRUE HIERARCHICAL Pattern extraction - Official sources have PRECEDENCE:
    1. Federal laws and regulations (precise patterns) - PRIORITY
    2. CDMX laws and regulations (precise patterns) - PRIORITY  
    3. Official CDMX government entities - PRIORITY
    4. Generic patterns ONLY for text spans NOT matched by official patterns
    """
    import time
    from datetime import datetime
    
    start_time = time.time()
    results = []
    
    print(f"🚀 Starting TRUE HIERARCHICAL extraction at {datetime.now().strftime('%H:%M:%S')}")
    print("=" * 70)
    
    # Load official patterns
    print("📋 Loading pattern groups...")
    federal_laws_patterns = [(pattern, category) for pattern, full_name, category in FEDERAL_LAWS_REGEX]
    cdmx_laws_patterns = [(pattern, category) for pattern, full_name, category in CDMX_LAWS_REGEX]
    official_cdmx_patterns = [(pattern.replace('\\\\', '\\'), category) for pattern, full_name, category in GOV_ENTITY_REGEX]
    
    # Generic fallback patterns
    legal_patterns = [
        (r'\b(?:Ley|LEY)\s+(?:Orgánica|General|Federal|de|del|para|sobre|[A-ZÁÉÍÓÚÑa-záéíóúñ]+)\s+[A-ZÁÉÍÓÚÑa-záéíóúñ\s]{8,150}', 'LAW_MENTION'),
        (r'\b(?:Código|CÓDIGO)\s+(?:de|del|para)\s+[A-ZÁÉÍÓÚÑa-záéíóúñ\s]{10,80}', 'LAW_CODE'),
        (r'\b(?:Reglamento|REGLAMENTO)\s+(?:de|del|para)\s+[A-ZÁÉÍÓÚÑa-záéíóúñ\s]{10,100}', 'REGULATION'),
        (r'\b(?:Norma|NORMA)\s+Oficial\s+Mexicana\s+[A-Z0-9\-]+', 'NOM'),
        (r'\b(?:Constitución|CONSTITUCIÓN)(?:\s+Política)?\s+(?:de|del)\s+[A-ZÁÉÍÓÚÑa-záéíóúñ\s]{5,80}', 'CONSTITUTION'),
    ]
    
    general_gov_patterns = [
        (r'\b(?:La\s+|la\s+)?(?:Secretaría|SECRETARÍA)(?:\s+(?:de|del)\s+[A-ZÁÉÍÓÚÑa-záéíóúñ\s]{5,80})?', 'SECRETARIA_GENERAL'),
        (r'\b(?:Alcaldía|ALCALDÍA|Alcaldías|ALCALDÍAS)\b', 'ALCALDIA_GENERAL'),
        (r'\b(?:SEDEMA|SEMARNAT|CONAGUA|PROFEPA|CONANP|COFEPRIS|CONDUSEF)\b', 'FEDERAL_AGENCY'),
        (r'\b(?:INE|INAI|CNDH|COFECE|IFT|INEGI|CONEVAL)\b', 'ORG_AUTONOMO_FED'),
        (r'\b(?:IMSS|ISSSTE|PEMEX|CFE)\b', 'PARAESTATAL_FED'),
        (r'\b(?:Instituto|Tribunal|Consejo|Comité|Coordinación|Organismo|Centro|Sistema|Registro)\s+(?:de|para|Público)\s+[A-ZÁÉÍÓÚÑa-záéíóúñ\s]{8,120}', 'ORG_GENERICO'),
        (r'\b(?:Universidad|UNIVERSIDAD)\s+[A-ZÁÉÍÓÚÑa-záéíóúñ\s]{5,50}', 'UNIVERSITY'),
    ]
    
    # Group by priority
    official_patterns = [
        ('FEDERAL_LAWS', federal_laws_patterns),
        ('CDMX_LAWS', cdmx_laws_patterns), 
        ('CDMX_OFFICIAL', official_cdmx_patterns)
    ]
    
    fallback_patterns = [
        ('LEGAL_DOCS', legal_patterns),
        ('GENERAL_GOV', general_gov_patterns)
    ]
    
    print(f"✅ OFFICIAL patterns loaded: {sum(len(patterns) for _, patterns in official_patterns)} (PRIORITY)")
    print(f"⚡ FALLBACK patterns loaded: {sum(len(patterns) for _, patterns in fallback_patterns)} (only for uncaptured text)")
    print(f"📊 Total documents to process: {len(df)}")
    print("=" * 70)
    
    # Progress tracking variables
    total_rows = len(df)
    official_matches_count = 0
    fallback_matches_count = 0
    blocked_fallback_count = 0
    processed_rows = 0
    
    for idx, row in df.iterrows():
        processed_rows += 1
        
        # Progress indicator every 100 rows
        if processed_rows % 100 == 0 or processed_rows == total_rows:
            elapsed = time.time() - start_time
            progress_pct = (processed_rows / total_rows) * 100
            print(f"📈 Progress: {processed_rows}/{total_rows} ({progress_pct:.1f}%) | "
                  f"Official: {official_matches_count} | Fallback: {fallback_matches_count} | "
                  f"Blocked: {blocked_fallback_count} | Time: {elapsed:.1f}s")
        
        text = str(row[text_column]) if pd.notna(row[text_column]) else ""
        section_title = row[section_column] if pd.notna(row[section_column]) else ""
        
        if not text.strip():
            continue
        
        # Track official matches by text position for this row
        official_matches = []
        row_official_count = 0
        row_fallback_count = 0
        row_blocked_count = 0
        
        # PASS 1: Extract all OFFICIAL patterns (these have precedence)
        for group_name, patterns in official_patterns:
            for pattern, entity_label in patterns:
                try:
                    matches = re.finditer(pattern, text, re.IGNORECASE)
                    for match in matches:
                        # Extract 30 words before and after the match
                        context = extract_context_window(text, match.start(), match.end(), words_before=30, words_after=30)
                        
                        match_info = {
                            'doc_hash': row.get('doc_hash', ''),
                            'row_id': row.get('row_id', ''),
                            'section_title': section_title,
                            'entity_text': match.group(0).strip(),
                            'entity_label': entity_label,
                            'pattern_group': group_name,
                            'before_context': context['before_context'],
                            'after_context': context['after_context'],
                            'full_context': context['full_context'],
                            'words_before_count': context['words_before_count'],
                            'words_after_count': context['words_after_count']
                        }
                        
                        official_matches.append((match.start(), match.end(), match_info))
                        results.append(match_info)
                        row_official_count += 1
                        
                except re.error as e:
                    print(f"❌ Regex error in {group_name}: {e}")
                    continue
        
        # PASS 2: Apply FALLBACK patterns only to uncovered text spans
        for group_name, patterns in fallback_patterns:
            for pattern, entity_label in patterns:
                try:
                    matches = re.finditer(pattern, text, re.IGNORECASE)
                    for match in matches:
                        match_start, match_end = match.start(), match.end()
                        
                        # Check overlap with official matches
                        overlaps_official = any(
                            max(match_start, off_start) < min(match_end, off_end)
                            for off_start, off_end, _ in official_matches
                        )
                        
                        if overlaps_official:
                            row_blocked_count += 1
                        else:
                            # Only add if no overlap with official patterns
                            # Extract 30 words before and after the match
                            context = extract_context_window(text, match.start(), match.end(), words_before=30, words_after=30)
                            
                            results.append({
                                'doc_hash': row.get('doc_hash', ''),
                                'row_id': row.get('row_id', ''),
                                'section_title': section_title,
                                'entity_text': match.group(0).strip(),
                                'entity_label': entity_label,
                                'pattern_group': group_name,
                                'before_context': context['before_context'],
                                'after_context': context['after_context'],
                                'full_context': context['full_context'],
                                'words_before_count': context['words_before_count'],
                                'words_after_count': context['words_after_count']
                            })
                            row_fallback_count += 1
                            
                except re.error as e:
                    print(f"❌ Regex error in {group_name}: {e}")
                    continue
        
        # Update global counters
        official_matches_count += row_official_count
        fallback_matches_count += row_fallback_count
        blocked_fallback_count += row_blocked_count
    
    # Final summary
    total_time = time.time() - start_time
    total_entities = len(results)
    
    print("=" * 70)
    print(f"✅ EXTRACTION COMPLETED at {datetime.now().strftime('%H:%M:%S')}")
    print(f"⏱️  Total processing time: {total_time:.2f} seconds")
    print(f"📊 Documents processed: {processed_rows}")
    print(f"🎯 Official matches: {official_matches_count}")
    print(f"⚡ Fallback matches: {fallback_matches_count}")
    print(f"🚫 Blocked duplicates: {blocked_fallback_count}")
    print(f"📈 Total entities extracted: {total_entities}")
    print(f"💡 Efficiency: {(official_matches_count / total_entities * 100):.1f}% from official patterns")
    print("=" * 70)
    
    return pd.DataFrame(results)

# %%
entities_df = extract_entities_with_true_hierarchy(df)

print(f"\n🎯 FINAL SUMMARY: Found {len(entities_df)} entities with TRUE HIERARCHICAL extraction")
# Out:
# 🚀 Starting TRUE HIERARCHICAL extraction at 15:34:09
# ======================================================================
# 📋 Loading pattern groups...
# ✅ OFFICIAL patterns loaded: 896 (PRIORITY)
# ⚡ FALLBACK patterns loaded: 12 (only for uncaptured text)
# 📊 Total documents to process: 11130
# ======================================================================
# 📈 Progress: 100/11130 (0.9%) | Official: 208 | Fallback: 413 | Blocked: 72 | Time: 15.8s
# 📈 Progress: 200/11130 (1.8%) | Official: 256 | Fallback: 599 | Blocked: 108 | Time: 30.0s
# 📈 Progress: 300/11130 (2.7%) | Official: 284 | Fallback: 714 | Blocked: 114 | Time: 43.7s
# 📈 Progress: 400/11130 (3.6%) | Official: 312 | Fallback: 850 | Blocked: 140 | Time: 57.2s
# 📈 Progress: 500/11130 (4.5%) | Official: 356 | Fallback: 940 | Blocked: 163 | Time: 71.0s
# 📈 Progress: 600/11130 (5.4%) | Official: 368 | Fallback: 978 | Blocked: 170 | Time: 85.1s
# 📈 Progress: 700/11130 (6.3%) | Official: 492 | Fallback: 1061 | Blocked: 236 | Time: 99.0s
# 📈 Progress: 800/11130 (7.2%) | Official: 540 | Fallback: 1112 | Blocked: 265 | Time: 112.4s
# 📈 Progress: 900/11130 (8.1%) | Official: 631 | Fallback: 1238 | Blocked: 310 | Time: 126.3s
# 📈 Progress: 1000/11130 (9.0%) | Official: 758 | Fallback: 1353 | Blocked: 373 | Time: 140.2s
# 📈 Progress: 1100/11130 (9.9%) | Official: 776 | Fallback: 1383 | Blocked: 388 | Time: 153.6s
# 📈 Progress: 1200/11130 (10.8%) | Official: 916 | Fallback: 1524 | Blocked: 472 | Time: 167.5s
# 📈 Progress: 1300/11130 (11.7%) | Official: 1032 | Fallback: 1676 | Blocked: 553 | Time: 181.6s
# 📈 Progress: 1400/11130 (12.6%) | Official: 1065 | Fallback: 1737 | Blocked: 570 | Time: 195.4s
# 📈 Progress: 1500/11130 (13.5%) | Official: 1202 | Fallback: 1851 | Blocked: 621 | Time: 209.6s
# 📈 Progress: 1600/11130 (14.4%) | Official: 1258 | Fallback: 1966 | Blocked: 641 | Time: 223.5s
# 📈 Progress: 1700/11130 (15.3%) | Official: 1328 | Fallback: 2165 | Blocked: 676 | Time: 238.2s
# 📈 Progress: 1800/11130 (16.2%) | Official: 1491 | Fallback: 2330 | Blocked: 789 | Time: 253.4s
# 📈 Progress: 1900/11130 (17.1%) | Official: 1542 | Fallback: 2440 | Blocked: 813 | Time: 267.5s
# 📈 Progress: 2000/11130 (18.0%) | Official: 1676 | Fallback: 2520 | Blocked: 856 | Time: 282.2s
# 📈 Progress: 2100/11130 (18.9%) | Official: 1860 | Fallback: 2687 | Blocked: 969 | Time: 297.7s
# 📈 Progress: 2200/11130 (19.8%) | Official: 1933 | Fallback: 2798 | Blocked: 1027 | Time: 311.4s
# 📈 Progress: 2300/11130 (20.7%) | Official: 2059 | Fallback: 2929 | Blocked: 1089 | Time: 325.7s
# 📈 Progress: 2400/11130 (21.6%) | Official: 2181 | Fallback: 3088 | Blocked: 1165 | Time: 339.5s
# 📈 Progress: 2500/11130 (22.5%) | Official: 2277 | Fallback: 3365 | Blocked: 1208 | Time: 354.0s
# 📈 Progress: 2600/11130 (23.4%) | Official: 2315 | Fallback: 3492 | Blocked: 1228 | Time: 367.5s
# 📈 Progress: 2700/11130 (24.3%) | Official: 2437 | Fallback: 3632 | Blocked: 1294 | Time: 381.5s
# 📈 Progress: 2800/11130 (25.2%) | Official: 2606 | Fallback: 3813 | Blocked: 1385 | Time: 396.1s
# 📈 Progress: 2900/11130 (26.1%) | Official: 2643 | Fallback: 3879 | Blocked: 1401 | Time: 409.5s
# 📈 Progress: 3000/11130 (27.0%) | Official: 2723 | Fallback: 4025 | Blocked: 1457 | Time: 423.5s
# 📈 Progress: 3100/11130 (27.9%) | Official: 2768 | Fallback: 4094 | Blocked: 1490 | Time: 437.0s
# 📈 Progress: 3200/11130 (28.8%) | Official: 2893 | Fallback: 4190 | Blocked: 1562 | Time: 450.8s
# 📈 Progress: 3300/11130 (29.6%) | Official: 2996 | Fallback: 4322 | Blocked: 1618 | Time: 465.1s
# 📈 Progress: 3400/11130 (30.5%) | Official: 3051 | Fallback: 4424 | Blocked: 1649 | Time: 478.6s
# 📈 Progress: 3500/11130 (31.4%) | Official: 3127 | Fallback: 4533 | Blocked: 1685 | Time: 492.6s
# 📈 Progress: 3600/11130 (32.3%) | Official: 3248 | Fallback: 4758 | Blocked: 1760 | Time: 506.5s
# 📈 Progress: 3700/11130 (33.2%) | Official: 3291 | Fallback: 4932 | Blocked: 1779 | Time: 520.0s
# 📈 Progress: 3800/11130 (34.1%) | Official: 3306 | Fallback: 5057 | Blocked: 1785 | Time: 533.4s
# 📈 Progress: 3900/11130 (35.0%) | Official: 3352 | Fallback: 5265 | Blocked: 1820 | Time: 548.0s
# 📈 Progress: 4000/11130 (35.9%) | Official: 3522 | Fallback: 5450 | Blocked: 1888 | Time: 563.1s
# 📈 Progress: 4100/11130 (36.8%) | Official: 3633 | Fallback: 5506 | Blocked: 1903 | Time: 576.8s
# 📈 Progress: 4200/11130 (37.7%) | Official: 3794 | Fallback: 5628 | Blocked: 1980 | Time: 590.7s
# 📈 Progress: 4300/11130 (38.6%) | Official: 3854 | Fallback: 5697 | Blocked: 2009 | Time: 604.1s
# 📈 Progress: 4400/11130 (39.5%) | Official: 3901 | Fallback: 5770 | Blocked: 2041 | Time: 618.3s
# 📈 Progress: 4500/11130 (40.4%) | Official: 3914 | Fallback: 5798 | Blocked: 2054 | Time: 632.1s
# 📈 Progress: 4600/11130 (41.3%) | Official: 3966 | Fallback: 5936 | Blocked: 2085 | Time: 646.4s
# 📈 Progress: 4700/11130 (42.2%) | Official: 4028 | Fallback: 6009 | Blocked: 2129 | Time: 660.3s
# 📈 Progress: 4800/11130 (43.1%) | Official: 4115 | Fallback: 6119 | Blocked: 2167 | Time: 674.8s
# 📈 Progress: 4900/11130 (44.0%) | Official: 4184 | Fallback: 6240 | Blocked: 2213 | Time: 688.2s
# 📈 Progress: 5000/11130 (44.9%) | Official: 4269 | Fallback: 6319 | Blocked: 2260 | Time: 702.0s
# 📈 Progress: 5100/11130 (45.8%) | Official: 4382 | Fallback: 6436 | Blocked: 2325 | Time: 715.9s
# 📈 Progress: 5200/11130 (46.7%) | Official: 4422 | Fallback: 6490 | Blocked: 2359 | Time: 729.3s
# 📈 Progress: 5300/11130 (47.6%) | Official: 4494 | Fallback: 6624 | Blocked: 2406 | Time: 743.2s
# 📈 Progress: 5400/11130 (48.5%) | Official: 4498 | Fallback: 6663 | Blocked: 2408 | Time: 756.8s
# 📈 Progress: 5500/11130 (49.4%) | Official: 4595 | Fallback: 6738 | Blocked: 2463 | Time: 770.9s
# 📈 Progress: 5600/11130 (50.3%) | Official: 4649 | Fallback: 6921 | Blocked: 2497 | Time: 785.3s
# 📈 Progress: 5700/11130 (51.2%) | Official: 4798 | Fallback: 7057 | Blocked: 2556 | Time: 799.9s
# 📈 Progress: 5800/11130 (52.1%) | Official: 4842 | Fallback: 7174 | Blocked: 2590 | Time: 813.5s
# 📈 Progress: 5900/11130 (53.0%) | Official: 4870 | Fallback: 7295 | Blocked: 2608 | Time: 827.3s
# 📈 Progress: 6000/11130 (53.9%) | Official: 4888 | Fallback: 7363 | Blocked: 2613 | Time: 841.8s
# 📈 Progress: 6100/11130 (54.8%) | Official: 4890 | Fallback: 7386 | Blocked: 2613 | Time: 855.2s
# 📈 Progress: 6200/11130 (55.7%) | Official: 5006 | Fallback: 7569 | Blocked: 2684 | Time: 869.5s
# 📈 Progress: 6300/11130 (56.6%) | Official: 5103 | Fallback: 7706 | Blocked: 2730 | Time: 883.8s
# 📈 Progress: 6400/11130 (57.5%) | Official: 5211 | Fallback: 7886 | Blocked: 2779 | Time: 898.2s
# 📈 Progress: 6500/11130 (58.4%) | Official: 5228 | Fallback: 7950 | Blocked: 2785 | Time: 911.5s
# 📈 Progress: 6600/11130 (59.3%) | Official: 5367 | Fallback: 8027 | Blocked: 2870 | Time: 925.6s
# 📈 Progress: 6700/11130 (60.2%) | Official: 5499 | Fallback: 8154 | Blocked: 2965 | Time: 940.0s
# 📈 Progress: 6800/11130 (61.1%) | Official: 5582 | Fallback: 8266 | Blocked: 3015 | Time: 953.6s
# 📈 Progress: 6900/11130 (62.0%) | Official: 5609 | Fallback: 8321 | Blocked: 3026 | Time: 967.2s
# 📈 Progress: 7000/11130 (62.9%) | Official: 5611 | Fallback: 8341 | Blocked: 3028 | Time: 980.7s
# 📈 Progress: 7100/11130 (63.8%) | Official: 5625 | Fallback: 8376 | Blocked: 3031 | Time: 994.1s
# 📈 Progress: 7200/11130 (64.7%) | Official: 5689 | Fallback: 8460 | Blocked: 3064 | Time: 1008.0s
# 📈 Progress: 7300/11130 (65.6%) | Official: 5792 | Fallback: 8678 | Blocked: 3104 | Time: 1021.9s
# 📈 Progress: 7400/11130 (66.5%) | Official: 5918 | Fallback: 8851 | Blocked: 3164 | Time: 1035.9s
# 📈 Progress: 7500/11130 (67.4%) | Official: 5976 | Fallback: 8974 | Blocked: 3178 | Time: 1049.3s
# 📈 Progress: 7600/11130 (68.3%) | Official: 6058 | Fallback: 9112 | Blocked: 3222 | Time: 1062.7s
# 📈 Progress: 7700/11130 (69.2%) | Official: 6093 | Fallback: 9227 | Blocked: 3236 | Time: 1076.1s
# 📈 Progress: 7800/11130 (70.1%) | Official: 6116 | Fallback: 9418 | Blocked: 3247 | Time: 1089.7s
# 📈 Progress: 7900/11130 (71.0%) | Official: 6121 | Fallback: 9619 | Blocked: 3250 | Time: 1103.0s
# 📈 Progress: 8000/11130 (71.9%) | Official: 6175 | Fallback: 9679 | Blocked: 3265 | Time: 1116.8s
# 📈 Progress: 8100/11130 (72.8%) | Official: 6248 | Fallback: 9730 | Blocked: 3288 | Time: 1130.8s
# 📈 Progress: 8200/11130 (73.7%) | Official: 6357 | Fallback: 9860 | Blocked: 3338 | Time: 1145.8s
# 📈 Progress: 8300/11130 (74.6%) | Official: 6591 | Fallback: 10099 | Blocked: 3509 | Time: 1160.4s
# 📈 Progress: 8400/11130 (75.5%) | Official: 6665 | Fallback: 10275 | Blocked: 3531 | Time: 1174.9s
# 📈 Progress: 8500/11130 (76.4%) | Official: 6803 | Fallback: 10410 | Blocked: 3601 | Time: 1188.8s
# 📈 Progress: 8600/11130 (77.3%) | Official: 6971 | Fallback: 10508 | Blocked: 3681 | Time: 1202.5s
# 📈 Progress: 8700/11130 (78.2%) | Official: 7025 | Fallback: 10560 | Blocked: 3721 | Time: 1215.9s
# 📈 Progress: 8800/11130 (79.1%) | Official: 7218 | Fallback: 10637 | Blocked: 3832 | Time: 1230.1s
# 📈 Progress: 8900/11130 (80.0%) | Official: 7318 | Fallback: 10665 | Blocked: 3894 | Time: 1243.8s
# 📈 Progress: 9000/11130 (80.9%) | Official: 7387 | Fallback: 10773 | Blocked: 3945 | Time: 1257.7s
# 📈 Progress: 9100/11130 (81.8%) | Official: 7458 | Fallback: 10887 | Blocked: 3981 | Time: 1271.8s
# 📈 Progress: 9200/11130 (82.7%) | Official: 7622 | Fallback: 10999 | Blocked: 4061 | Time: 1286.2s
# 📈 Progress: 9300/11130 (83.6%) | Official: 7707 | Fallback: 11088 | Blocked: 4143 | Time: 1300.1s
# 📈 Progress: 9400/11130 (84.5%) | Official: 7821 | Fallback: 11249 | Blocked: 4227 | Time: 1314.6s
# 📈 Progress: 9500/11130 (85.4%) | Official: 7876 | Fallback: 11373 | Blocked: 4269 | Time: 1328.3s
# 📈 Progress: 9600/11130 (86.3%) | Official: 7989 | Fallback: 11475 | Blocked: 4329 | Time: 1342.2s
# 📈 Progress: 9700/11130 (87.2%) | Official: 8051 | Fallback: 11575 | Blocked: 4377 | Time: 1356.1s
# 📈 Progress: 9800/11130 (88.1%) | Official: 8254 | Fallback: 11750 | Blocked: 4482 | Time: 1370.5s
# 📈 Progress: 9900/11130 (88.9%) | Official: 8323 | Fallback: 11870 | Blocked: 4533 | Time: 1385.0s
# 📈 Progress: 10000/11130 (89.8%) | Official: 8447 | Fallback: 11973 | Blocked: 4573 | Time: 1399.6s
# 📈 Progress: 10100/11130 (90.7%) | Official: 8513 | Fallback: 12020 | Blocked: 4577 | Time: 1413.5s
# 📈 Progress: 10200/11130 (91.6%) | Official: 8597 | Fallback: 12105 | Blocked: 4618 | Time: 1427.7s
# 📈 Progress: 10300/11130 (92.5%) | Official: 8653 | Fallback: 12236 | Blocked: 4654 | Time: 1441.3s
# 📈 Progress: 10400/11130 (93.4%) | Official: 8701 | Fallback: 12328 | Blocked: 4678 | Time: 1454.8s
# 📈 Progress: 10500/11130 (94.3%) | Official: 8753 | Fallback: 12624 | Blocked: 4696 | Time: 1468.5s
# 📈 Progress: 10600/11130 (95.2%) | Official: 8811 | Fallback: 12808 | Blocked: 4736 | Time: 1482.0s
# 📈 Progress: 10700/11130 (96.1%) | Official: 8877 | Fallback: 12907 | Blocked: 4791 | Time: 1496.5s
# 📈 Progress: 10800/11130 (97.0%) | Official: 8899 | Fallback: 12935 | Blocked: 4810 | Time: 1510.0s
# 📈 Progress: 10900/11130 (97.9%) | Official: 8943 | Fallback: 13061 | Blocked: 4839 | Time: 1524.3s
# 📈 Progress: 11000/11130 (98.8%) | Official: 9020 | Fallback: 13190 | Blocked: 4895 | Time: 1538.6s
# 📈 Progress: 11100/11130 (99.7%) | Official: 9028 | Fallback: 13273 | Blocked: 4901 | Time: 1551.8s
# 📈 Progress: 11130/11130 (100.0%) | Official: 9029 | Fallback: 13286 | Blocked: 4901 | Time: 1555.7s
# ======================================================================
# ✅ EXTRACTION COMPLETED at 16:00:04
# ⏱️  Total processing time: 1555.88 seconds
# 📊 Documents processed: 11130
# 🎯 Official matches: 9029
# ⚡ Fallback matches: 13287
# 🚫 Blocked duplicates: 4901
# 📈 Total entities extracted: 22316
# 💡 Efficiency: 40.5% from official patterns
# ======================================================================
#
# 🎯 FINAL SUMMARY: Found 22316 entities with TRUE HIERARCHICAL extraction

# %%
# Display sample results with context
print("📋 Sample of extracted entities with context:")
print("=" * 120)

# Show first 3 results with full context
sample_results = entities_df.head(3)
for idx, row in sample_results.iterrows():
    priority = "🔥 OFFICIAL" if row['pattern_group'] in ['FEDERAL_LAWS', 'CDMX_LAWS', 'CDMX_OFFICIAL'] else "⚡ FALLBACK"
    print(f"{priority} Entity: {row['entity_text']}")
    print(f"   📍 Label: {row['entity_label']} | Group: {row['pattern_group']}")
    print(f"   📝 Context: {row['full_context'][:150]}{'...' if len(row['full_context']) > 150 else ''}")
    print(f"   📊 Words: {row['words_before_count']} before + {row['words_after_count']} after")
    print()

print("=" * 120)
print(f"📈 Column structure: {list(entities_df.columns)}")

# Show basic statistics
entities_df.head()
# Out:
# 📋 Sample of extracted entities with context:
# ========================================================================================================================
# ⚡ FALLBACK Entity: Constitución Política de los Estados Unidos Mexicanos
#    📍 Label: CONSTITUTION | Group: LEGAL_DOCS
#    📝 Context: en todo lo concerniente a su régimen interior y a su organización política y administrativa . 5 . Las autoridades de la Ciudad ejercen las facultades ...
#    📊 Words: 30 before + 30 after
#
# ⚡ FALLBACK Entity: Constitución Política de los Estados Unidos Mexicanos
#    📍 Label: CONSTITUTION | Group: LEGAL_DOCS
#    📝 Context: depende su competitividad , productividad y prosperidad . 8 . El territorio de la Ciudad de México es el que actualmente tiene de conformidad con el a...
#    📊 Words: 30 before + 26 after
#
# ⚡ FALLBACK Entity: sistema de división de poderes
#    📍 Label: ORG_GENERICO | Group: GENERAL_GOV
#    📝 Context: y se instituye para beneficio de éste . 3 . La Ciudad adopta para su gobierno la forma republicana , democrática , representativa , laica y popular , ...
#    📊 Words: 30 before + 30 after
#
# ========================================================================================================================
# 📈 Column structure: ['doc_hash', 'row_id', 'section_title', 'entity_text', 'entity_label', 'pattern_group', 'before_context', 'after_context', 'full_context', 'words_before_count', 'words_after_count']
#    doc_hash             row_id section_title  \
# 0  F823AF8C  F823AF8C_ARTCULO1    Artículo 1
# 1  F823AF8C  F823AF8C_ARTCULO1    Artículo 1
# 2  F823AF8C  F823AF8C_ARTCULO1    Artículo 1
# 3  F823AF8C  F823AF8C_ARTCULO3    Artículo 3
# 4  F823AF8C  F823AF8C_ARTCULO4    Artículo 4
#
#                                          entity_text  entity_label  \
# 0  Constitución Política de los Estados Unidos Me...  CONSTITUTION
# 1  Constitución Política de los Estados Unidos Me...  CONSTITUTION
# 2                     sistema de división de poderes  ORG_GENERICO
# 3  Constitución Política de los Estados Unidos Me...  CONSTITUTION
# 4  Constitución Política de los Estados Unidos Me...  CONSTITUTION
#
#   pattern_group                                     before_context  \
# 0    LEGAL_DOCS  en todo lo concerniente a su régimen interior ...
# 1    LEGAL_DOCS  depende su competitividad , productividad y pr...
# 2   GENERAL_GOV  y se instituye para beneficio de éste . 3 . La...
# 3    LEGAL_DOCS  ingreso , la dignificación del trabajo y el sa...
# 4    LEGAL_DOCS  derechos humanos A . De la protección de los d...
#
#                                        after_context  \
# 0  , todas aquellas que ésta no concede expresame...
# 1  . Sus límites geográficos son los fijados por ...
# 2  , pluralismo político y participación social ....
# 3  , la igualdad sustantiva , la no discriminació...
# 4  , en los tratados e instrumentos internacional...
#
#                                         full_context  words_before_count  \
# 0  en todo lo concerniente a su régimen interior ...                  30
# 1  depende su competitividad , productividad y pr...                  30
# 2  y se instituye para beneficio de éste . 3 . La...                  30
# 3  ingreso , la dignificación del trabajo y el sa...                  30
# 4  derechos humanos A . De la protección de los d...                  30
#
#    words_after_count
# 0                 30
# 1                 26
# 2                 30
# 3                 30
# 4                 30

# %%
# Save entity recognition results with IDs
entities_output = '/Users/alexa/Projects/cdmx_kg/data/entities_extracted_complete.csv'
entities_df.to_csv(entities_output, index=False, encoding='utf-8-sig')
print(f"Entities saved to: {entities_output}")
# Out:
# Entities saved to: /Users/alexa/Projects/cdmx_kg/data/entities_extracted_complete.csv
